# %% [markdown]
# <div style="border-bottom:2px solid #4CAF50; margin-top:30px;">
#   <h2 style="color:#2c3e50;">Playstore Data Analysis</h2>
# </div>

# %% [markdown]
# * <span style="color:red">The data given the project based on playstore data analysis,
# where the library pandas used to convert the csv file into proper tabulare format

# %% [markdown]
# * <span style="color:red">pandas is for data manipulation

# %% [markdown]
# * <span style="color:red"> Matplotlib & seaborn is for data visualization

# %% [markdown]
# ## importing library

# %%
import pandas as pd

# %% [markdown]
# * <span style="color:red">The library used here is pandas, used to manipulate the data

# %%
df = pd.read_csv("googleplaystore - googleplaystore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# * <span style="color:red">To inspect the data from above row , where the user can decide how many by inputing the no. of rows

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %% [markdown]
# * <span style="color:red">To inspect the data from the below row,same as the head function

# %%
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %% [markdown]
# * <span style="color:red">to check the datatype

# %%
df.dtypes
# Out:
# App                   str
# Category              str
# Rating            float64
# Reviews               str
# Size                  str
# Installs              str
# Type                  str
# Price                 str
# Content Rating        str
# Genres                str
# Last Updated          str
# Current Ver           str
# Android Ver           str
# dtype: object

# %% [markdown]
# * <span style="color:red;"> Display column names

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %% [markdown]
# * <span style="color:red"> Display no. of rows and columns

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# * <span style="color:red"> Basic info about the data

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB

# %% [markdown]
# - From the dataset we identified that there plenty of data missing in various columns

# %% [markdown]
# - no data given= 10841
# - no column= 13
# - memory usage= 1.1 MB
# - No. of values missing on rating= 1474
# - No. of valus missing on type= 1
# - No. of valus missing on current ver= 8
# - No. of valus missing on abdroid ver= 3
# - No. of valus missing on content rating= 1
# - No. of string variables = 12
# - No. of float variable= 1

# %% [markdown]
# ## |<span style="color:red">Selecting "App" column

# %%
df['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: str

# %% [markdown]
# # |<span style="color:red"> For selecting multiple coloumn

# %%
new = df[['Rating','Size']]
new
# Out:
#        Rating                Size
# 0         4.1                 19M
# 1         3.9                 14M
# 2         4.7                8.7M
# 3         4.5                 25M
# 4         4.3                2.8M
# ...       ...                 ...
# 10836     4.5                 53M
# 10837     5.0                3.6M
# 10838     NaN                9.5M
# 10839     4.5  Varies with device
# 10840     4.5                 19M
#
# [10841 rows x 2 columns]

# %% [markdown]
# # |<span style="color:red"> To filter the data

# %%
df[df['Rating']<3]
# Out:
#                                                   App         Category  \
# 477                                        Calculator           DATING
# 518                     Just She - Top Lesbian Dating           DATING
# 520    EliteSingles – Dating for Single Professionals           DATING
# 527                            Sugar Daddy Dating App           DATING
# 528                                Adult Dirty Emojis           DATING
# ...                                               ...              ...
# 10624                           Employ Florida Mobile         BUSINESS
# 10665                     SB · FN 1870 Mobile Banking          FINANCE
# 10677                                 Pint - FN Theme  PERSONALIZATION
# 10757                    Fisher-Price® Smart Connect™            TOOLS
# 10766                          FreedomPop Diagnostics            TOOLS
#
#        Rating Reviews  Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# -<span style="color:red"> filtered Apps having less than 3

# %% [markdown]
# ## <span style="color:red">Apps with 15M and above downloads

# %%
df[df['Size']>='15M']
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## <span style="color:red"> Free Applications

# %%
new = df[df['Type']=='Free']
new
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## <span style="color:red">Apps Updated After 2017

# %%
df[df['Last Updated']=='January 7, 2018']
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1587   Pronunciation and know the name of the caller ...       LIFESTYLE
# 7778               Chest Opener for CR - The Circle Game          FAMILY
# 9041                                Differential Dx Free         MEDICAL
# 10111                                          Third Eye           TOOLS
# 10283                        Bank FD Interest Calculator         FINANCE
#
#        Rating Reviews                Size    Installs  Type Price  \
# 0         4.1     159                 19M     10,000+  Free     0
# 1587      4.6    2167                1.4M    500,000+  Free     0
# 7778      NaN      68                2.7M      5,000+  Free     0
# 9041      4.0     238  Varies with device     50,000+  Free     0
# 10111     4.4   19877                4.5M  1,000,000+  Free     0
# ...

# %% [markdown]
# ## <span style="color:red"> Applications Available For Everyone

# %%
df[df['Content Rating']=='Everyone']
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 5                             Paper flowers instructions  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# ## | <span style="color:red">Multiple Filtering

# %%
df[(df['Rating']> 4.5)&(df['Type']=='Free')]
# Out:
#                                                      App             Category  \
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10810                                  Fr Lupupa Sermons             BUSINESS
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %% [markdown]
# ## |<span style="color:red">  Now for selecting rows

# %% [markdown]
# Selecting based on single values

# %%
df.iloc[6]
# Out:
# App               Smoke Effect Photo Maker - Smoke Editor
# Category                                   ART_AND_DESIGN
# Rating                                                3.8
# Reviews                                               178
# Size                                                  19M
# Installs                                          50,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                       Art & Design
# Last Updated                               April 26, 2018
# Current Ver                                           1.1
# Android Ver                                  4.0.3 and up
# Name: 6, dtype: object

# %% [markdown]
# | <span style="color:red">Selecting rows based on interval using the index value

# %%
df.iloc[4:10]
# Out:
#                                        App        Category  Rating Reviews  \
# 4    Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3     967
# 5               Paper flowers instructions  ART_AND_DESIGN     4.4     167
# 6  Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8     178
# 7                         Infinite Painter  ART_AND_DESIGN     4.1   36815
# 8                     Garden Coloring Book  ART_AND_DESIGN     4.4   13791
# 9            Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7     121
#
#    Size    Installs  Type Price Content Rating                   Genres  \
# 4  2.8M    100,000+  Free     0       Everyone  Art & Design;Creativity
# 5  5.6M     50,000+  Free     0       Everyone             Art & Design
# 6   19M     50,000+  Free     0       Everyone             Art & Design
# 7   29M  1,000,000+  Free     0       Everyone             Art & Design
# 8   33M  1,000,000+  Free     0       Everyone             Art & Design
# ...

# %% [markdown]
# ## |<span style="color:red">Locating specific feature on specific row

# %%
df.loc[30, 'App']
# Out:
# 'Pink Silver Bow Keyboard Theme'

# %% [markdown]
# |<span style="color:red"> Locating multiple feature on multiple row

# %%
df.loc[500,['App','Rating','Size']]
# Out:
# App       Blendr - Chat, Flirt & Meet
# Rating                            4.0
# Size               Varies with device
# Name: 500, dtype: object

# %% [markdown]
# | <span style="color:red">To rename the column

# %% [markdown]
# renaming the column without changing the primary data table

# %%
df.rename(columns={'App':'Application'})
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# <span style="color:red"><code> (here you can see the by printing df we get the primary data table where it doesnt change)</code>

# %% [markdown]
# | <span style="color:red">
# Rename the column by changing the primary data table

# %%
df.rename(columns={'App':'Application'},inplace=True)

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# <code>changing current version to Latest version</cude>

# %%
df.rename(columns={'Current Ver':'Latest Version'},inplace=True)

# %% [markdown]
# <code><span style="color:red">shows how many types of genres and what are they</code>

# %%
df['Genres'].value_counts()
# Out:
# Genres
# Tools                       842
# Entertainment               623
# Education                   549
# Medical                     463
# Business                    460
#                            ...
# Strategy;Education            1
# Racing;Pretend Play           1
# Communication;Creativity      1
# February 11, 2018             1
# Strategy;Creativity           1
# Name: count, Length: 120, dtype: int64

# %%
df.iloc[30]
# Out:
# Application       Pink Silver Bow Keyboard Theme
# Category                          ART_AND_DESIGN
# Rating                                       4.2
# Reviews                                     1120
# Size                                        9.2M
# Installs                                100,000+
# Type                                        Free
# Price                                          0
# Content Rating                          Everyone
# Genres                              Art & Design
# Last Updated                       July 12, 2018
# Latest Version                       6.7.12.2018
# Android Ver                         4.0.3 and up
# Name: 30, dtype: object

# %% [markdown]
# <h1 style="border-bottom:2px solid #ccc; padding-bottom:5px;">
# Data cleaning
# </h1>

# %% [markdown]
# ### cleaning Numerical columns with charactors

# %% [markdown]
# <code> remove text unit and convert to numbers</code>

# %%
df['Size'] = pd.to_numeric(
    df['Size']
    .astype(str)                                     # ← astype
    .str.replace(r'[^0-9.]', '', regex=True)         # ← regex
    .replace('', None),
    errors='coerce'
)

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# <code>removing the '+' for better comparison </code>

# %%
df['Installs'] = pd.to_numeric(
    df['Installs']
    .astype(str)                                     # ← astype
    .str.replace(r'[^0-9.]', '', regex=True)         # ← regex
    .replace('', None),
    errors='coerce'
)

# %% [markdown]
# <code>now both Size and Installs are float type Data</code>

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application     10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            9146 non-null   float64
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Latest Version  10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(3), str(10)
# memory usage: 1.1 MB

# %% [markdown]
# <code>changing "price" column from str to float

# %%
df['Price'] = pd.to_numeric(
    df['Price']
    .astype(str)                                     # ← astype
    .str.replace(r'[^0-9.]', '', regex=True)         # ← regex
    .replace('', None),
    errors='coerce'
)

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application     10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            9146 non-null   float64
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  str
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Latest Version  10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(4), str(9)
# memory usage: 1.1 MB

# %%
df['Price'].value_counts()
# Out:
# Price
# 0.00      10040
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
#           ...
# 3.61          1
# 394.99        1
# 1.26          1
# 1.20          1
# 1.04          1
# Name: count, Length: 92, dtype: int64

# %% [markdown]
# <code>parse last_updated as datetime</code>

# %% [markdown]
# * changing the last updated coulumn from string to float

# %%
df["Last Updated"] = pd.to_datetime(df["Last Updated"], errors='coerce')

# %% [markdown]
# <code>#df["Hour"] = df["last_updated"]

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
def convert_size(size):
    size = str(size).strip().upper()    # normalize everything to uppercase
    if size.endswith('M'):
        return float(size[:-1])
    elif size.endswith('K'):            # handles both 'k' and 'K'
        return float(size[:-1]) / 1024
    else:
        return None

df['Size_MB'] = df['Size'].apply(convert_size)

# Verify
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.dtypes
# Out:
# Application                  str
# Category                     str
# Rating                   float64
# Reviews                      str
# Size                     float64
# Installs                 float64
# Type                         str
# Price                    float64
# Content Rating               str
# Genres                       str
# Last Updated      datetime64[us]
# Latest Version               str
# Android Ver                  str
# Size_MB                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application     10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            9146 non-null   float64
#  5   Installs        10840 non-null  float64
#  6   Type            10840 non-null  str
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10840 non-null  datetime64[us]
#  11  Latest Version  10833 non-null  str
#  12  Android Ver     10838 non-null  str
#  13  Size_MB         0 non-null      object
# dtypes: datetime64[us](1), float64(4), object(1), str(8)
# memory usage: 1.2+ MB

# %%
df['Size']
# Out:
# 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10841, dtype: float64

# %%
df['Size'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10836    53.0
# 10837     3.6
# 10838     9.5
# 10839     NaN
# 10840    19.0
# Name: Size, Length: 10841, dtype: float64>

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# <code> Now for removing columns that are not required for analysis</code>

# %%
df.drop(columns=['Latest Version'],inplace=True)

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull()
# Out:
#        Application  Category  Rating  Reviews   Size  Installs   Type  Price  \
# 0            False     False   False    False  False     False  False  False
# 1            False     False   False    False  False     False  False  False
# 2            False     False   False    False  False     False  False  False
# 3            False     False   False    False  False     False  False  False
# 4            False     False   False    False  False     False  False  False
# ...            ...       ...     ...      ...    ...       ...    ...    ...
# 10836        False     False   False    False  False     False  False  False
# 10837        False     False   False    False  False     False  False  False
# 10838        False     False    True    False  False     False  False  False
# 10839        False     False   False    False   True     False  False  False
# 10840        False     False   False    False  False     False  False  False
#
# ...

# %% [markdown]
# ## <code>for handling missing values

# %%
df.isnull().sum()
# Out:
# Application           0
# Category              0
# Rating             1474
# Reviews               0
# Size               1695
# Installs              1
# Type                  1
# Price                 1
# Content Rating        1
# Genres                0
# Last Updated          1
# Android Ver           3
# Size_MB           10841
# dtype: int64

# %%
df.drop(columns=['Size'],inplace=True)

# %%
df.drop(columns=['Size_MB'],inplace=True)

# %%
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# Application          0
# Category             0
# Rating            1474
# Reviews              0
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Android Ver          3
# dtype: int64

# %%
df['Rating'].fillna(df['Rating'].median(), inplace=True)
# Out:
# C:\Users\noufi\AppData\Local\Temp\ipykernel_21028\3537473122.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Rating'].fillna(df['Rating'].median(), inplace=True)
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    4.3
# 10839    4.5
# ...

# %%
df.isnull().sum()
# Out:
# Application          0
# Category             0
# Rating            1474
# Reviews              0
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Android Ver          3
# dtype: int64

# %% [markdown]
# <code>to fix missing value on "Rating" by adding median of the given data

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].median())

# %%
df.isnull().sum()
# Out:
# Application       0
# Category          0
# Rating            0
# Reviews           0
# Installs          1
# Type              1
# Price             1
# Content Rating    1
# Genres            0
# Last Updated      1
# Android Ver       3
# dtype: int64

# %% [markdown]
# ## <code> To drop the Row

# %%
df.dropna(subset=['Android Ver','Installs','Type','Price','Content Rating','Last Updated'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Application       0
# Category          0
# Rating            0
# Reviews           0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Android Ver       0
# dtype: int64

# %% [markdown]
# Here we dropped the dropped the data with missing value
